# %% [markdown]
# # Credit Card Fraud Detection::

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g7RwgEQI-pTwV_LGxz8mdcHEPxIB0v5qg6AvI_W1KA3H2VgV2MR3yo
# Mounted at /content/drive

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# ## Identify fraudulent credit card transactions.

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/drive/MyDrive/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
X=df.drop(columns="Class")
y=df['Class']

# %%
non_fraud=df[df["Class"]==0]
fraud=df[df["Class"]==1]
non_fraud=non_fraud.sample(3*fraud.shape[0])
data = fraud.append(non_fraud, ignore_index=True)
x_data= data.drop(columns="Class", axis=0)
label = data["Class"]

# %%
data
# Out:
#           Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0        406.0 -2.312227  1.951992 -1.609851  ...  0.261145 -0.143276    0.00      1
# 1        472.0 -3.043541 -3.157307  1.088463  ... -0.252773  0.035764  529.00      1
# 2       4462.0 -2.303350  1.759247 -0.359745  ...  0.039566 -0.153029  239.93      1
# 3       6986.0 -4.397974  1.358367 -2.592844  ... -0.827136  0.849573   59.00      1
# 4       7519.0  1.234235  3.019740 -4.304597  ... -0.010016  0.146793    1.00      1
# ...        ...       ...       ...       ...  ...       ...       ...     ...    ...
# 1963   62345.0 -0.809681  1.224628  0.263897  ... -0.112717  0.118569   75.40      0
# 1964   66083.0 -1.088752  0.714853  2.335800  ... -0.064960 -0.006019    2.49      0
# 1965  156369.0  2.060854 -0.096996 -1.074450  ... -0.074953 -0.061193    1.98      0
# 1966  111093.0  2.095880  0.065258 -1.431455  ... -0.020660 -0.056916    1.00      0
# 1967  137415.0  2.257734 -1.293812 -0.896147  ...  0.009927 -0.038101   25.00      0
#
# [1968 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_labels, test_labels=train_test_split(x_data, label, test_size=0.3, random_state=1, stratify = label)

# %%
X_train
# Out:
#           Time        V1        V2  ...       V27       V28    Amount
# 769   0.280801 -0.104481  0.460743  ... -0.219943 -2.595949 -0.391678
# 1877 -0.115502  0.220460 -0.343713  ...  0.132995  0.369597 -0.330542
# 1468 -1.038362  0.538320 -0.280280  ... -0.152786 -0.023646 -0.137563
# 922   1.246234  0.318750 -1.876652  ... -0.465845  0.308005  4.737632
# 1059 -1.793729  0.139442  0.046921  ...  0.080142  0.282997 -0.345654
# ...        ...       ...       ...  ...       ...       ...       ...
# 377   0.842671  0.458618  0.460237  ...  0.323179 -0.172859 -0.386354
# 1625 -0.035647  0.756907 -0.317351  ... -0.101114 -0.211431 -0.387256
# 1143 -0.182010  0.239711 -0.566240  ... -0.277939 -0.534365  0.128015
# 1794 -1.230666 -0.462821 -0.248628  ... -1.994981  0.497723 -0.365317
# 917   1.487430  0.747925 -0.272151  ... -0.070448 -0.089453 -0.307402
#
# [1377 rows x 30 columns]

# %%
train_mean = train_data.mean(axis=0) # taking the mean of 
train_data -= train_mean
train_std = train_data.std(axis=0)
train_data /= train_std
test_data -= train_mean
test_data /= train_std

# %%
from keras import models , layers
from keras import regularizers

# %%
model = models.Sequential()
model.add(layers.Dense(20, activation='relu',kernel_regularizer=regularizers.l2(0.001), input_shape=(train_data.shape[1],)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(6, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss= 'binary_crossentropy', optimizer= 'rmsprop', metrics=['accuracy'])

# %%
model.fit(train_data, train_labels, epochs=100 , validation_split=0.3)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 11ms/step - loss: 1.1103 - accuracy: 0.4746 - val_loss: 0.7468 - val_accuracy: 0.5386
# Epoch 2/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.8723 - accuracy: 0.5763 - val_loss: 0.7143 - val_accuracy: 0.7826
# Epoch 3/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.8148 - accuracy: 0.6260 - val_loss: 0.6986 - val_accuracy: 0.7681
# Epoch 4/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.7705 - accuracy: 0.6846 - val_loss: 0.6876 - val_accuracy: 0.7415
# Epoch 5/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.7370 - accuracy: 0.7185 - val_loss: 0.6713 - val_accuracy: 0.7415
# Epoch 6/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6821 - accuracy: 0.7436 - val_loss: 0.6572 - val_accuracy: 0.7415
# Epoch 7/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6614 - accuracy: 0.7826 - val_loss: 0.6432 - val_accuracy: 0.7415
# Epoch 8/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6645 - accuracy: 0.7762 - val_loss: 0.6324 - val_accuracy: 0.7440
# Epoch 9/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6664 - accuracy: 0.7686 - val_loss: 0.6187 - val_accuracy: 0.7464
# Epoch 10/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6448 - accuracy: 0.7692 - val_loss: 0.6056 - val_accuracy: 0.7488
# Epoch 11/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6600 - accuracy: 0.7687 - val_loss: 0.5932 - val_accuracy: 0.7512
# Epoch 12/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6220 - accuracy: 0.7859 - val_loss: 0.5758 - val_accuracy: 0.7778
# Epoch 13/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5964 - accuracy: 0.7662 - val_loss: 0.5538 - val_accuracy: 0.8043
# Epoch 14/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.8008 - val_loss: 0.5371 - val_accuracy: 0.8068
# Epoch 15/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5663 - accuracy: 0.8203 - val_loss: 0.5160 - val_accuracy: 0.8237
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5882 - accuracy: 0.7832 - val_loss: 0.4952 - val_accuracy: 0.8309
# Epoch 17/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5841 - accuracy: 0.8166 - val_loss: 0.4729 - val_accuracy: 0.8454
# Epoch 18/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5607 - accuracy: 0.8252 - val_loss: 0.4489 - val_accuracy: 0.8599
# Epoch 19/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5369 - accuracy: 0.8145 - val_loss: 0.4347 - val_accuracy: 0.8671
# Epoch 20/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4728 - accuracy: 0.8611 - val_loss: 0.4182 - val_accuracy: 0.8720
# Epoch 21/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5209 - accuracy: 0.8288 - val_loss: 0.4063 - val_accuracy: 0.8816
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4782 - accuracy: 0.8462 - val_loss: 0.3865 - val_accuracy: 0.8913
# Epoch 23/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4811 - accuracy: 0.8454 - val_loss: 0.3625 - val_accuracy: 0.9034
# Epoch 24/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4533 - accuracy: 0.8523 - val_loss: 0.3417 - val_accuracy: 0.9203
# Epoch 25/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4837 - accuracy: 0.8686 - val_loss: 0.3267 - val_accuracy: 0.9324
# Epoch 26/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5269 - accuracy: 0.8593 - val_loss: 0.3149 - val_accuracy: 0.9324
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8853 - val_loss: 0.3000 - val_accuracy: 0.9348
# Epoch 28/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4572 - accuracy: 0.8635 - val_loss: 0.2886 - val_accuracy: 0.9348
# Epoch 29/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4253 - accuracy: 0.8672 - val_loss: 0.2759 - val_accuracy: 0.9444
# Epoch 30/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8770 - val_loss: 0.2656 - val_accuracy: 0.9517
# Epoch 31/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3714 - accuracy: 0.8876 - val_loss: 0.2545 - val_accuracy: 0.9517
# Epoch 32/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8898 - val_loss: 0.2464 - val_accuracy: 0.9541
# Epoch 33/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3946 - accuracy: 0.8901 - val_loss: 0.2383 - val_accuracy: 0.9541
# Epoch 34/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.8869 - val_loss: 0.2331 - val_accuracy: 0.9541
# Epoch 35/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.9204 - val_loss: 0.2283 - val_accuracy: 0.9541
# Epoch 36/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3728 - accuracy: 0.8755 - val_loss: 0.2241 - val_accuracy: 0.9541
# Epoch 37/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8954 - val_loss: 0.2208 - val_accuracy: 0.9541
# Epoch 38/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3177 - accuracy: 0.9137 - val_loss: 0.2168 - val_accuracy: 0.9541
# Epoch 39/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.9046 - val_loss: 0.2149 - val_accuracy: 0.9541
# Epoch 40/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3519 - accuracy: 0.8977 - val_loss: 0.2137 - val_accuracy: 0.9565
# Epoch 41/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3166 - accuracy: 0.9089 - val_loss: 0.2124 - val_accuracy: 0.9565
# Epoch 42/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.8997 - val_loss: 0.2106 - val_accuracy: 0.9565
# Epoch 43/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3432 - accuracy: 0.9017 - val_loss: 0.2109 - val_accuracy: 0.9565
# Epoch 44/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2890 - accuracy: 0.9130 - val_loss: 0.2084 - val_accuracy: 0.9589
# Epoch 45/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2895 - accuracy: 0.9261 - val_loss: 0.2079 - val_accuracy: 0.9589
# Epoch 46/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2977 - accuracy: 0.9160 - val_loss: 0.2097 - val_accuracy: 0.9589
# Epoch 47/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3237 - accuracy: 0.9171 - val_loss: 0.2115 - val_accuracy: 0.9589
# Epoch 48/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.9173 - val_loss: 0.2115 - val_accuracy: 0.9589
# Epoch 49/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2656 - accuracy: 0.9321 - val_loss: 0.2111 - val_accuracy: 0.9589
# Epoch 50/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2583 - accuracy: 0.9342 - val_loss: 0.2100 - val_accuracy: 0.9589
# Epoch 51/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3273 - accuracy: 0.9054 - val_loss: 0.2109 - val_accuracy: 0.9589
# Epoch 52/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2688 - accuracy: 0.9249 - val_loss: 0.2113 - val_accuracy: 0.9565
# Epoch 53/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2837 - accuracy: 0.9132 - val_loss: 0.2120 - val_accuracy: 0.9565
# Epoch 54/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.9410 - val_loss: 0.2131 - val_accuracy: 0.9565
# Epoch 55/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2983 - accuracy: 0.9304 - val_loss: 0.2144 - val_accuracy: 0.9565
# Epoch 56/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2517 - accuracy: 0.9359 - val_loss: 0.2148 - val_accuracy: 0.9565
# Epoch 57/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2858 - accuracy: 0.9251 - val_loss: 0.2146 - val_accuracy: 0.9565
# Epoch 58/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2580 - accuracy: 0.9347 - val_loss: 0.2131 - val_accuracy: 0.9614
# Epoch 59/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2368 - accuracy: 0.9489 - val_loss: 0.2137 - val_accuracy: 0.9565
# Epoch 60/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2771 - accuracy: 0.9396 - val_loss: 0.2153 - val_accuracy: 0.9589
# Epoch 61/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2341 - accuracy: 0.9418 - val_loss: 0.2171 - val_accuracy: 0.9614
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2153 - accuracy: 0.9546 - val_loss: 0.2187 - val_accuracy: 0.9589
# Epoch 63/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2478 - accuracy: 0.9284 - val_loss: 0.2189 - val_accuracy: 0.9589
# Epoch 64/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2429 - accuracy: 0.9362 - val_loss: 0.2215 - val_accuracy: 0.9589
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1941 - accuracy: 0.9643 - val_loss: 0.2204 - val_accuracy: 0.9589
# Epoch 66/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2698 - accuracy: 0.9299 - val_loss: 0.2205 - val_accuracy: 0.9589
# Epoch 67/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.9427 - val_loss: 0.2225 - val_accuracy: 0.9589
# Epoch 68/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2212 - accuracy: 0.9424 - val_loss: 0.2222 - val_accuracy: 0.9589
# Epoch 69/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2343 - accuracy: 0.9447 - val_loss: 0.2233 - val_accuracy: 0.9614
# Epoch 70/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2155 - accuracy: 0.9499 - val_loss: 0.2221 - val_accuracy: 0.9589
# Epoch 71/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2508 - accuracy: 0.9458 - val_loss: 0.2222 - val_accuracy: 0.9589
# Epoch 72/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1831 - accuracy: 0.9546 - val_loss: 0.2234 - val_accuracy: 0.9614
# Epoch 73/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2297 - accuracy: 0.9440 - val_loss: 0.2242 - val_accuracy: 0.9614
# Epoch 74/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9556 - val_loss: 0.2261 - val_accuracy: 0.9614
# Epoch 75/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9490 - val_loss: 0.2256 - val_accuracy: 0.9614
# Epoch 76/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9328 - val_loss: 0.2265 - val_accuracy: 0.9614
# Epoch 77/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2391 - accuracy: 0.9407 - val_loss: 0.2271 - val_accuracy: 0.9614
# Epoch 78/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2191 - accuracy: 0.9406 - val_loss: 0.2277 - val_accuracy: 0.9614
# Epoch 79/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2228 - accuracy: 0.9412 - val_loss: 0.2260 - val_accuracy: 0.9614
# Epoch 80/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9425 - val_loss: 0.2254 - val_accuracy: 0.9614
# Epoch 81/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2165 - accuracy: 0.9362 - val_loss: 0.2288 - val_accuracy: 0.9614
# Epoch 82/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2008 - accuracy: 0.9528 - val_loss: 0.2286 - val_accuracy: 0.9614
# Epoch 83/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1960 - accuracy: 0.9484 - val_loss: 0.2295 - val_accuracy: 0.9614
# Epoch 84/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2027 - accuracy: 0.9561 - val_loss: 0.2310 - val_accuracy: 0.9589
# Epoch 85/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2476 - accuracy: 0.9336 - val_loss: 0.2298 - val_accuracy: 0.9589
# Epoch 86/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2163 - accuracy: 0.9513 - val_loss: 0.2284 - val_accuracy: 0.9589
# Epoch 87/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2406 - accuracy: 0.9383 - val_loss: 0.2322 - val_accuracy: 0.9589
# Epoch 88/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2775 - accuracy: 0.9273 - val_loss: 0.2246 - val_accuracy: 0.9614
# Epoch 89/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2314 - accuracy: 0.9383 - val_loss: 0.2279 - val_accuracy: 0.9614
# Epoch 90/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1843 - accuracy: 0.9582 - val_loss: 0.2271 - val_accuracy: 0.9589
# Epoch 91/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2143 - accuracy: 0.9376 - val_loss: 0.2281 - val_accuracy: 0.9589
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1566 - accuracy: 0.9683 - val_loss: 0.2272 - val_accuracy: 0.9589
# Epoch 93/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2210 - accuracy: 0.9371 - val_loss: 0.2257 - val_accuracy: 0.9589
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9650 - val_loss: 0.2245 - val_accuracy: 0.9589
# Epoch 95/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2131 - accuracy: 0.9439 - val_loss: 0.2257 - val_accuracy: 0.9589
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1906 - accuracy: 0.9521 - val_loss: 0.2277 - val_accuracy: 0.9589
# Epoch 97/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1776 - accuracy: 0.9567 - val_loss: 0.2243 - val_accuracy: 0.9589
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1817 - accuracy: 0.9514 - val_loss: 0.2270 - val_accuracy: 0.9589
# Epoch 99/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1981 - accuracy: 0.9469 - val_loss: 0.2241 - val_accuracy: 0.9589
# Epoch 100/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2139 - accuracy: 0.9398 - val_loss: 0.2248 - val_accuracy: 0.9589

# %%
model.evaluate(test_data,test_labels)
# Out:
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.9492
# [0.34911996126174927, 0.9492385983467102]

# %%
prediction=model.predict(test_data)

# %%
for i in prediction:
  if i>0.9:
    print("fraud cases area ",i)
# Out:
# fraud cases area  [1.]
# fraud cases area  [0.99999785]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9697614]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9999994]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9867792]
# fraud cases area  [1.]
# fraud cases area  [0.99999976]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9999992]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9899063]
# fraud cases area  [0.9997853]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.99999976]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9999813]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9999585]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.99999774]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9764143]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.99995387]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.98928535]
# fraud cases area  [0.9999995]
# fraud cases area  [1.]
# fraud cases area  [0.9999994]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9840997]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [1.]
# fraud cases area  [0.9259627]

# %%
import tensorflow as tf
tf.math.confusion_matrix(labels= test_labels, predictions=prediction )
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[442,   1],
#        [ 41, 107]], dtype=int32)>
